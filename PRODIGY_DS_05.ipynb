# %%
#importing libraries
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings 
warnings.filterwarnings('ignore')

# %%
#load and read the file
df=pd.read_csv(r"C:\Users\TANUVEDU\Downloads\accident  Dataset.csv")
df.head()
# Out:
#        Time Day_of_week Age_band_of_driver Sex_of_driver   Educational_level  \
# 0  17:02:00      Monday              18-30          Male   Above high school
# 1  17:02:00      Monday              31-50          Male  Junior high school
# 2  17:02:00      Monday              18-30          Male  Junior high school
# 3   1:06:00      Sunday              18-30          Male  Junior high school
# 4   1:06:00      Sunday              18-30          Male  Junior high school
#
#   Vehicle_driver_relation Driving_experience      Type_of_vehicle  \
# 0                Employee              1-2yr           Automobile
# 1                Employee         Above 10yr  Public (> 45 seats)
# 2                Employee              1-2yr      Lorry (41?100Q)
# 3                Employee             5-10yr  Public (> 45 seats)
# 4                Employee              2-5yr                  NaN
#
#   Owner_of_vehicle Service_year_of_vehicle  ... Vehicle_movement  \
# 0            Owner              Above 10yr  ...   Going straight
# 1            Owner                 5-10yrs  ...   Going straight
# 2            Owner                     NaN  ...   Going straight
# 3     Governmental                     NaN  ...   Going straight
# 4            Owner                 5-10yrs  ...   Going straight
#
#     Casualty_class Sex_of_casualty Age_band_of_casualty Casualty_severity  \
# 0               na              na                   na                na
# 1               na              na                   na                na
# 2  Driver or rider            Male                31-50                 3
# 3       Pedestrian          Female                18-30                 3
# 4               na              na                   na                na
#
#   Work_of_casuality Fitness_of_casuality Pedestrian_movement  \
# 0               NaN                  NaN    Not a Pedestrian
# 1               NaN                  NaN    Not a Pedestrian
# 2            Driver                  NaN    Not a Pedestrian
# 3            Driver               Normal    Not a Pedestrian
# 4               NaN                  NaN    Not a Pedestrian
#
#             Cause_of_accident Accident_severity
# 0             Moving Backward     Slight Injury
# 1                  Overtaking     Slight Injury
# 2   Changing lane to the left    Serious Injury
# 3  Changing lane to the right     Slight Injury
# 4                  Overtaking     Slight Injury
#
# [5 rows x 32 columns]

# %%
df.shape
# Out:
# (12316, 32)

# %%
df.describe()
# Out:
#        Number_of_vehicles_involved  Number_of_casualties
# count                 12316.000000          12316.000000
# mean                      2.040679              1.548149
# std                       0.688790              1.007179
# min                       1.000000              1.000000
# 25%                       2.000000              1.000000
# 50%                       2.000000              1.000000
# 75%                       2.000000              2.000000
# max                       7.000000              8.000000

# %%
df.describe(include="all")
# Out:
#             Time Day_of_week Age_band_of_driver Sex_of_driver  \
# count      12316       12316              12316         12316
# unique      1074           7                  5             3
# top     15:30:00      Friday              18-30          Male
# freq         120        2041               4271         11437
# mean         NaN         NaN                NaN           NaN
# std          NaN         NaN                NaN           NaN
# min          NaN         NaN                NaN           NaN
# 25%          NaN         NaN                NaN           NaN
# 50%          NaN         NaN                NaN           NaN
# 75%          NaN         NaN                NaN           NaN
# max          NaN         NaN                NaN           NaN
#
#          Educational_level Vehicle_driver_relation Driving_experience  \
# count                11575                   11737              11487
# unique                   7                       4                  7
# top     Junior high school                Employee             5-10yr
# freq                  7619                    9627               3363
# mean                   NaN                     NaN                NaN
# std                    NaN                     NaN                NaN
# min                    NaN                     NaN                NaN
# 25%                    NaN                     NaN                NaN
# 50%                    NaN                     NaN                NaN
# 75%                    NaN                     NaN                NaN
# max                    NaN                     NaN                NaN
#
#        Type_of_vehicle Owner_of_vehicle Service_year_of_vehicle  ...  \
# count            11366            11834                    8388  ...
# unique              17                4                       6  ...
# top         Automobile            Owner                 Unknown  ...
# freq              3205            10459                    2883  ...
# mean               NaN              NaN                     NaN  ...
# std                NaN              NaN                     NaN  ...
# min                NaN              NaN                     NaN  ...
# 25%                NaN              NaN                     NaN  ...
# 50%                NaN              NaN                     NaN  ...
# 75%                NaN              NaN                     NaN  ...
# max                NaN              NaN                     NaN  ...
#
#        Vehicle_movement   Casualty_class Sex_of_casualty Age_band_of_casualty  \
# count             12008            12316           12316                12316
# unique               13                4               3                    6
# top      Going straight  Driver or rider            Male                   na
# freq               8158             4944            5253                 4443
# mean                NaN              NaN             NaN                  NaN
# std                 NaN              NaN             NaN                  NaN
# min                 NaN              NaN             NaN                  NaN
# 25%                 NaN              NaN             NaN                  NaN
# 50%                 NaN              NaN             NaN                  NaN
# 75%                 NaN              NaN             NaN                  NaN
# max                 NaN              NaN             NaN                  NaN
#
#        Casualty_severity Work_of_casuality Fitness_of_casuality  \
# count              12316              9118                 9681
# unique                 4                 7                    5
# top                    3            Driver               Normal
# freq                7076              5903                 9608
# mean                 NaN               NaN                  NaN
# std                  NaN               NaN                  NaN
# min                  NaN               NaN                  NaN
# 25%                  NaN               NaN                  NaN
# 50%                  NaN               NaN                  NaN
# 75%                  NaN               NaN                  NaN
# max                  NaN               NaN                  NaN
#
#        Pedestrian_movement Cause_of_accident Accident_severity
# count                12316             12316             12316
# unique                   9                20                 3
# top       Not a Pedestrian     No distancing     Slight Injury
# freq                 11390              2263             10415
# mean                   NaN               NaN               NaN
# std                    NaN               NaN               NaN
# min                    NaN               NaN               NaN
# 25%                    NaN               NaN               NaN
# 50%                    NaN               NaN               NaN
# 75%                    NaN               NaN               NaN
# max                    NaN               NaN               NaN
#
# [11 rows x 32 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12316 entries, 0 to 12315
# Data columns (total 32 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Time                         12316 non-null  object
#  1   Day_of_week                  12316 non-null  object
#  2   Age_band_of_driver           12316 non-null  object
#  3   Sex_of_driver                12316 non-null  object
#  4   Educational_level            11575 non-null  object
#  5   Vehicle_driver_relation      11737 non-null  object
#  6   Driving_experience           11487 non-null  object
#  7   Type_of_vehicle              11366 non-null  object
#  8   Owner_of_vehicle             11834 non-null  object
#  9   Service_year_of_vehicle      8388 non-null   object
#  10  Defect_of_vehicle            7889 non-null   object
#  11  Area_accident_occured        12077 non-null  object
#  12  Lanes_or_Medians             11931 non-null  object
#  13  Road_allignment              12174 non-null  object
#  14  Types_of_Junction            11429 non-null  object
#  15  Road_surface_type            12144 non-null  object
#  16  Road_surface_conditions      12316 non-null  object
#  17  Light_conditions             12316 non-null  object
#  18  Weather_conditions           12316 non-null  object
#  19  Type_of_collision            12161 non-null  object
#  20  Number_of_vehicles_involved  12316 non-null  int64
#  21  Number_of_casualties         12316 non-null  int64
#  22  Vehicle_movement             12008 non-null  object
#  23  Casualty_class               12316 non-null  object
#  24  Sex_of_casualty              12316 non-null  object
#  25  Age_band_of_casualty         12316 non-null  object
#  26  Casualty_severity            12316 non-null  object
#  27  Work_of_casuality            9118 non-null   object
#  28  Fitness_of_casuality         9681 non-null   object
#  29  Pedestrian_movement          12316 non-null  object
#  30  Cause_of_accident            12316 non-null  object
#  31  Accident_severity            12316 non-null  object
# dtypes: int64(2), object(30)
# memory usage: 3.0+ MB

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df['Accident_severity'].value_counts()
# Out:
# Accident_severity
# Slight Injury     10415
# Serious Injury     1743
# Fatal injury        158
# Name: count, dtype: int64

# %%
sns.countplot(x = df['Accident_severity'])
plt.title('Distribution of Accident severity')
# Out:
# Text(0.5, 1.0, 'Distribution of Accident severity')

# %%
df.isna().sum()
# Out:
# Time                              0
# Day_of_week                       0
# Age_band_of_driver                0
# Sex_of_driver                     0
# Educational_level               741
# Vehicle_driver_relation         579
# Driving_experience              829
# Type_of_vehicle                 950
# Owner_of_vehicle                482
# Service_year_of_vehicle        3928
# Defect_of_vehicle              4427
# Area_accident_occured           239
# Lanes_or_Medians                385
# Road_allignment                 142
# Types_of_Junction               887
# Road_surface_type               172
# Road_surface_conditions           0
# Light_conditions                  0
# Weather_conditions                0
# Type_of_collision               155
# Number_of_vehicles_involved       0
# Number_of_casualties              0
# Vehicle_movement                308
# Casualty_class                    0
# Sex_of_casualty                   0
# Age_band_of_casualty              0
# Casualty_severity                 0
# Work_of_casuality              3198
# Fitness_of_casuality           2635
# Pedestrian_movement               0
# Cause_of_accident                 0
# Accident_severity                 0
# dtype: int64

# %%
df.drop(['Service_year_of_vehicle','Defect_of_vehicle','Work_of_casuality', 'Fitness_of_casuality','Time'],
        axis = 1, inplace = True)
df.head()
# Out:
#   Day_of_week Age_band_of_driver Sex_of_driver   Educational_level  \
# 0      Monday              18-30          Male   Above high school
# 1      Monday              31-50          Male  Junior high school
# 2      Monday              18-30          Male  Junior high school
# 3      Sunday              18-30          Male  Junior high school
# 4      Sunday              18-30          Male  Junior high school
#
#   Vehicle_driver_relation Driving_experience      Type_of_vehicle  \
# 0                Employee              1-2yr           Automobile
# 1                Employee         Above 10yr  Public (> 45 seats)
# 2                Employee              1-2yr      Lorry (41?100Q)
# 3                Employee             5-10yr  Public (> 45 seats)
# 4                Employee              2-5yr                  NaN
#
#   Owner_of_vehicle Area_accident_occured   Lanes_or_Medians  ...  \
# 0            Owner     Residential areas                NaN  ...
# 1            Owner          Office areas  Undivided Two way  ...
# 2            Owner    Recreational areas              other  ...
# 3     Governmental          Office areas              other  ...
# 4            Owner      Industrial areas              other  ...
#
#   Number_of_vehicles_involved Number_of_casualties Vehicle_movement  \
# 0                           2                    2   Going straight
# 1                           2                    2   Going straight
# 2                           2                    2   Going straight
# 3                           2                    2   Going straight
# 4                           2                    2   Going straight
#
#     Casualty_class Sex_of_casualty Age_band_of_casualty Casualty_severity  \
# 0               na              na                   na                na
# 1               na              na                   na                na
# 2  Driver or rider            Male                31-50                 3
# 3       Pedestrian          Female                18-30                 3
# 4               na              na                   na                na
#
#    Pedestrian_movement           Cause_of_accident Accident_severity
# 0     Not a Pedestrian             Moving Backward     Slight Injury
# 1     Not a Pedestrian                  Overtaking     Slight Injury
# 2     Not a Pedestrian   Changing lane to the left    Serious Injury
# 3     Not a Pedestrian  Changing lane to the right     Slight Injury
# 4     Not a Pedestrian                  Overtaking     Slight Injury
#
# [5 rows x 27 columns]

# %%
categorical=[i for i in df.columns if df[i].dtype=='O']
print('The categorical variables are',categorical)
# Out:
# The categorical variables are ['Day_of_week', 'Age_band_of_driver', 'Sex_of_driver', 'Educational_level', 'Vehicle_driver_relation', 'Driving_experience', 'Type_of_vehicle', 'Owner_of_vehicle', 'Area_accident_occured', 'Lanes_or_Medians', 'Road_allignment', 'Types_of_Junction', 'Road_surface_type', 'Road_surface_conditions', 'Light_conditions', 'Weather_conditions', 'Type_of_collision', 'Vehicle_movement', 'Casualty_class', 'Sex_of_casualty', 'Age_band_of_casualty', 'Casualty_severity', 'Pedestrian_movement', 'Cause_of_accident', 'Accident_severity']

# %%
for i in categorical:
    df[i].fillna(df[i].mode()[0],inplace=True)

# %%
df.isna().sum()
# Out:
# Day_of_week                    0
# Age_band_of_driver             0
# Sex_of_driver                  0
# Educational_level              0
# Vehicle_driver_relation        0
# Driving_experience             0
# Type_of_vehicle                0
# Owner_of_vehicle               0
# Area_accident_occured          0
# Lanes_or_Medians               0
# Road_allignment                0
# Types_of_Junction              0
# Road_surface_type              0
# Road_surface_conditions        0
# Light_conditions               0
# Weather_conditions             0
# Type_of_collision              0
# Number_of_vehicles_involved    0
# Number_of_casualties           0
# Vehicle_movement               0
# Casualty_class                 0
# Sex_of_casualty                0
# Age_band_of_casualty           0
# Casualty_severity              0
# Pedestrian_movement            0
# Cause_of_accident              0
# Accident_severity              0
# dtype: int64

# %%
sns.scatterplot(x=df['Number_of_casualties'], y=df['Number_of_vehicles_involved'], hue=df['Accident_severity'])
# Out:
# <Axes: xlabel='Number_of_casualties', ylabel='Number_of_vehicles_involved'>

# %%
df[['Number_of_vehicles_involved', 'Number_of_casualties']].corr(method='pearson')
# Out:
#                              Number_of_vehicles_involved  Number_of_casualties
# Number_of_vehicles_involved                          NaN                   NaN
# Number_of_casualties                                 NaN                   NaN

# %%
sns.jointplot(x='Number_of_casualties',y='Number_of_vehicles_involved',data=df)

# %%
numeric_df = df.select_dtypes(include=['number'])
correlation_matrix = numeric_df.corr()
print(correlation_matrix)
# Out:
#                              Number_of_vehicles_involved  Number_of_casualties
# Number_of_vehicles_involved                     1.000000              0.213427
# Number_of_casualties                            0.213427              1.000000

# %%
numeric_df = df.select_dtypes(include=['number'])
correlation_matrix = numeric_df.corr()
print(correlation_matrix)
# Out:
#                              Day_of_week  Age_band_of_driver  Sex_of_driver  \
# Day_of_week                     1.000000            0.019993       0.009986
# Age_band_of_driver              0.019993            1.000000      -0.351878
# Sex_of_driver                   0.009986           -0.351878       1.000000
# Educational_level              -0.004517            0.013613       0.004967
# Vehicle_driver_relation         0.003303           -0.005841       0.011035
# Driving_experience             -0.010062           -0.013407       0.009855
# Type_of_vehicle                -0.002417            0.004830      -0.003757
# Owner_of_vehicle                0.001417            0.005405      -0.009489
# Area_accident_occured           0.003281            0.011472      -0.000274
# Lanes_or_Medians               -0.009320            0.008176      -0.012529
# Road_allignment                -0.008505            0.000486      -0.002238
# Types_of_Junction              -0.026669           -0.028025       0.004920
# Road_surface_type               0.009832            0.001058       0.003112
# Road_surface_conditions        -0.008294           -0.032533       0.031601
# Light_conditions                0.036280           -0.007766       0.037390
# Weather_conditions             -0.003248            0.025482      -0.006179
# Type_of_collision               0.003026            0.000496      -0.011513
# Number_of_vehicles_involved    -0.002303            0.003370      -0.042337
# Number_of_casualties           -0.050042           -0.054474       0.048503
# Vehicle_movement               -0.027643           -0.006562       0.007058
# Casualty_class                  0.006661            0.005386       0.003335
# Sex_of_casualty                 0.001461            0.011358      -0.006046
# Age_band_of_casualty           -0.003642            0.000043       0.014191
# Casualty_severity               0.001512            0.003565       0.002474
# Pedestrian_movement             0.000250            0.000372       0.006981
# Cause_of_accident               0.010516           -0.000703      -0.000598
# Accident_severity              -0.002730            0.013185       0.004977
#
#                              Educational_level  Vehicle_driver_relation  \
# Day_of_week                          -0.004517                 0.003303
# Age_band_of_driver                    0.013613                -0.005841
# Sex_of_driver                         0.004967                 0.011035
# Educational_level                     1.000000                -0.076866
# Vehicle_driver_relation              -0.076866                 1.000000
# Driving_experience                    0.057625                 0.016686
# Type_of_vehicle                       0.005447                -0.003481
# Owner_of_vehicle                     -0.012486                 0.014860
# Area_accident_occured                -0.006854                 0.021997
# Lanes_or_Medians                     -0.002756                 0.004656
# Road_allignment                      -0.010213                -0.013660
# Types_of_Junction                     0.014798                -0.011548
# Road_surface_type                     0.014345                -0.001312
# Road_surface_conditions               0.008614                 0.004257
# Light_conditions                     -0.000290                 0.001351
# Weather_conditions                   -0.000242                -0.015357
# Type_of_collision                    -0.009477                -0.005568
# Number_of_vehicles_involved           0.012522                 0.008868
# Number_of_casualties                  0.003698                 0.018222
# Vehicle_movement                      0.004248                 0.005631
# Casualty_class                        0.005382                -0.002817
# Sex_of_casualty                       0.007483                -0.000664
# Age_band_of_casualty                  0.008226                 0.008115
# Casualty_severity                     0.004950                -0.003230
# Pedestrian_movement                   0.000177                 0.015803
# Cause_of_accident                    -0.000451                -0.010753
# Accident_severity                    -0.001471                -0.011253
#
#                              Driving_experience  Type_of_vehicle  \
# Day_of_week                           -0.010062        -0.002417
# Age_band_of_driver                    -0.013407         0.004830
# Sex_of_driver                          0.009855        -0.003757
# Educational_level                      0.057625         0.005447
# Vehicle_driver_relation                0.016686        -0.003481
# Driving_experience                     1.000000         0.014333
# Type_of_vehicle                        0.014333         1.000000
# Owner_of_vehicle                       0.000144        -0.012463
# Area_accident_occured                 -0.000290        -0.007631
# Lanes_or_Medians                      -0.010444        -0.020156
# Road_allignment                       -0.015602        -0.020910
# Types_of_Junction                      0.009245        -0.005553
# Road_surface_type                      0.020872         0.013972
# Road_surface_conditions               -0.003696         0.019018
# Light_conditions                      -0.015577        -0.003739
# Weather_conditions                    -0.000084         0.006903
# Type_of_collision                      0.012574         0.025911
# Number_of_vehicles_involved           -0.007993         0.001781
# Number_of_casualties                  -0.007118         0.003022
# Vehicle_movement                       0.004794         0.010841
# Casualty_class                        -0.002783        -0.006116
# Sex_of_casualty                       -0.000214        -0.011247
# Age_band_of_casualty                  -0.010891        -0.008934
# Casualty_severity                     -0.004952        -0.001679
# Pedestrian_movement                   -0.018790         0.010500
# Cause_of_accident                     -0.007728        -0.004200
# Accident_severity                      0.000509        -0.003709
#
#                              Owner_of_vehicle  Area_accident_occured  \
# Day_of_week                          0.001417               0.003281
# Age_band_of_driver                   0.005405               0.011472
# Sex_of_driver                       -0.009489              -0.000274
# Educational_level                   -0.012486              -0.006854
# Vehicle_driver_relation              0.014860               0.021997
# Driving_experience                   0.000144              -0.000290
# Type_of_vehicle                     -0.012463              -0.007631
# Owner_of_vehicle                     1.000000              -0.021942
# Area_accident_occured               -0.021942               1.000000
# Lanes_or_Medians                     0.045938               0.022760
# Road_allignment                      0.011427              -0.025859
# Types_of_Junction                    0.012105               0.014580
# Road_surface_type                   -0.010030              -0.004275
# Road_surface_conditions             -0.000976              -0.007290
# Light_conditions                     0.013693              -0.013597
# Weather_conditions                  -0.009544               0.003127
# Type_of_collision                    0.000271              -0.003940
# Number_of_vehicles_involved          0.008505              -0.017875
# Number_of_casualties                -0.004504              -0.004690
# Vehicle_movement                     0.022287               0.004691
# Casualty_class                       0.003196               0.011325
# Sex_of_casualty                      0.007335               0.010546
# Age_band_of_casualty                 0.011667               0.008001
# Casualty_severity                    0.010517               0.014565
# Pedestrian_movement                  0.023517               0.000949
# Cause_of_accident                    0.016550              -0.009589
# Accident_severity                   -0.010960              -0.018374
#
#                              Lanes_or_Medians  ...  \
# Day_of_week                         -0.009320  ...
# Age_band_of_driver                   0.008176  ...
# Sex_of_driver                       -0.012529  ...
# Educational_level                   -0.002756  ...
# Vehicle_driver_relation              0.004656  ...
# Driving_experience                  -0.010444  ...
# Type_of_vehicle                     -0.020156  ...
# Owner_of_vehicle                     0.045938  ...
# Area_accident_occured                0.022760  ...
# Lanes_or_Medians                     1.000000  ...
# Road_allignment                      0.042815  ...
# Types_of_Junction                   -0.002125  ...
# Road_surface_type                   -0.026511  ...
# Road_surface_conditions              0.011774  ...
# Light_conditions                     0.004624  ...
# Weather_conditions                   0.005828  ...
# Type_of_collision                    0.007008  ...
# Number_of_vehicles_involved         -0.000571  ...
# Number_of_casualties                 0.002188  ...
# Vehicle_movement                    -0.002089  ...
# Casualty_class                       0.006034  ...
# Sex_of_casualty                      0.000516  ...
# Age_band_of_casualty                 0.006677  ...
# Casualty_severity                    0.006183  ...
# Pedestrian_movement                  0.005848  ...
# Cause_of_accident                    0.016384  ...
# Accident_severity                   -0.011844  ...
#
#                              Number_of_vehicles_involved  \
# Day_of_week                                    -0.002303
# Age_band_of_driver                              0.003370
# Sex_of_driver                                  -0.042337
# Educational_level                               0.012522
# Vehicle_driver_relation                         0.008868
# Driving_experience                             -0.007993
# Type_of_vehicle                                 0.001781
# Owner_of_vehicle                                0.008505
# Area_accident_occured                          -0.017875
# Lanes_or_Medians                               -0.000571
# Road_allignment                                -0.000911
# Types_of_Junction                              -0.020170
# Road_surface_type                              -0.002561
# Road_surface_conditions                        -0.023574
# Light_conditions                                0.030009
# Weather_conditions                             -0.038666
# Type_of_collision                               0.005616
# Number_of_vehicles_involved                     1.000000
# Number_of_casualties                            0.213427
# Vehicle_movement                               -0.005796
# Casualty_class                                  0.006072
# Sex_of_casualty                                 0.007118
# Age_band_of_casualty                            0.003051
# Casualty_severity                               0.012786
# Pedestrian_movement                             0.020466
# Cause_of_accident                              -0.021512
# Accident_severity                               0.096023
#
#                              Number_of_casualties  Vehicle_movement  \
# Day_of_week                             -0.050042         -0.027643
# Age_band_of_driver                      -0.054474         -0.006562
# Sex_of_driver                            0.048503          0.007058
# Educational_level                        0.003698          0.004248
# Vehicle_driver_relation                  0.018222          0.005631
# Driving_experience                      -0.007118          0.004794
# Type_of_vehicle                          0.003022          0.010841
# Owner_of_vehicle                        -0.004504          0.022287
# Area_accident_occured                   -0.004690          0.004691
# Lanes_or_Medians                         0.002188         -0.002089
# Road_allignment                         -0.011434         -0.004267
# Types_of_Junction                       -0.043389         -0.010761
# Road_surface_type                       -0.003704          0.000382
# Road_surface_conditions                  0.072828         -0.004667
# Light_conditions                        -0.055116          0.022327
# Weather_conditions                       0.014138          0.007648
# Type_of_collision                       -0.020694          0.000640
# Number_of_vehicles_involved              0.213427         -0.005796
# Number_of_casualties                     1.000000          0.002599
# Vehicle_movement                         0.002599          1.000000
# Casualty_class                          -0.012820          0.001281
# Sex_of_casualty                         -0.004589          0.000101
# Age_band_of_casualty                    -0.008637          0.006919
# Casualty_severity                       -0.009643          0.002772
# Pedestrian_movement                      0.006019         -0.008456
# Cause_of_accident                       -0.022096          0.002336
# Accident_severity                       -0.045339         -0.010386
#
#                              Casualty_class  Sex_of_casualty  \
# Day_of_week                        0.006661         0.001461
# Age_band_of_driver                 0.005386         0.011358
# Sex_of_driver                      0.003335        -0.006046
# Educational_level                  0.005382         0.007483
# Vehicle_driver_relation           -0.002817        -0.000664
# Driving_experience                -0.002783        -0.000214
# Type_of_vehicle                   -0.006116        -0.011247
# Owner_of_vehicle                   0.003196         0.007335
# Area_accident_occured              0.011325         0.010546
# Lanes_or_Medians                   0.006034         0.000516
# Road_allignment                   -0.003117        -0.006122
# Types_of_Junction                  0.002423         0.005234
# Road_surface_type                  0.002922        -0.003816
# Road_surface_conditions           -0.002313         0.022057
# Light_conditions                  -0.012499        -0.011276
# Weather_conditions                 0.003313         0.014465
# Type_of_collision                  0.012333         0.006854
# Number_of_vehicles_involved        0.006072         0.007118
# Number_of_casualties              -0.012820        -0.004589
# Vehicle_movement                   0.001281         0.000101
# Casualty_class                     1.000000         0.679936
# Sex_of_casualty                    0.679936         1.000000
# Age_band_of_casualty               0.802169         0.705230
# Casualty_severity                  0.765640         0.773514
# Pedestrian_movement               -0.075248         0.168455
# Cause_of_accident                  0.011625         0.005016
# Accident_severity                  0.014075         0.003708
#
#                              Age_band_of_casualty  Casualty_severity  \
# Day_of_week                             -0.003642           0.001512
# Age_band_of_driver                       0.000043           0.003565
# Sex_of_driver                            0.014191           0.002474
# Educational_level                        0.008226           0.004950
# Vehicle_driver_relation                  0.008115          -0.003230
# Driving_experience                      -0.010891          -0.004952
# Type_of_vehicle                         -0.008934          -0.001679
# Owner_of_vehicle                         0.011667           0.010517
# Area_accident_occured                    0.008001           0.014565
# Lanes_or_Medians                         0.006677           0.006183
# Road_allignment                          0.005540          -0.005039
# Types_of_Junction                        0.007946           0.017271
# Road_surface_type                       -0.004704          -0.008926
# Road_surface_conditions                  0.006415           0.010456
# Light_conditions                        -0.011780           0.004327
# Weather_conditions                      -0.002245           0.011337
# Type_of_collision                        0.004962           0.010915
# Number_of_vehicles_involved              0.003051           0.012786
# Number_of_casualties                    -0.008637          -0.009643
# Vehicle_movement                         0.006919           0.002772
# Casualty_class                           0.802169           0.765640
# Sex_of_casualty                          0.705230           0.773514
# Age_band_of_casualty                     1.000000           0.745549
# Casualty_severity                        0.745549           1.000000
# Pedestrian_movement                      0.062065           0.146947
# Cause_of_accident                        0.010536           0.010614
# Accident_severity                        0.025510           0.006531
#
#                              Pedestrian_movement  Cause_of_accident  \
# Day_of_week                             0.000250           0.010516
# Age_band_of_driver                      0.000372          -0.000703
# Sex_of_driver                           0.006981          -0.000598
# Educational_level                       0.000177          -0.000451
# Vehicle_driver_relation                 0.015803          -0.010753
# Driving_experience                     -0.018790          -0.007728
# Type_of_vehicle                         0.010500          -0.004200
# Owner_of_vehicle                        0.023517           0.016550
# Area_accident_occured                   0.000949          -0.009589
# Lanes_or_Medians                        0.005848           0.016384
# Road_allignment                         0.005219          -0.000287
# Types_of_Junction                      -0.008855          -0.006561
# Road_surface_type                      -0.006762          -0.015085
# Road_surface_conditions                 0.006157           0.002811
# Light_conditions                        0.014229           0.004213
# Weather_conditions                      0.018292           0.001320
# Type_of_collision                      -0.008081           0.011757
# Number_of_vehicles_involved             0.020466          -0.021512
# Number_of_casualties                    0.006019          -0.022096
# Vehicle_movement                       -0.008456           0.002336
# Casualty_class                         -0.075248           0.011625
# Sex_of_casualty                         0.168455           0.005016
# Age_band_of_casualty                    0.062065           0.010536
# Casualty_severity                       0.146947           0.010614
# Pedestrian_movement                     1.000000           0.001523
# Cause_of_accident                       0.001523           1.000000
# Accident_severity                       0.013082           0.008040
#
#                              Accident_severity
# Day_of_week                          -0.002730
# Age_band_of_driver                    0.013185
# Sex_of_driver                         0.004977
# Educational_level                    -0.001471
# Vehicle_driver_relation              -0.011253
# Driving_experience                    0.000509
# Type_of_vehicle                      -0.003709
# Owner_of_vehicle                     -0.010960
# Area_accident_occured                -0.018374
# Lanes_or_Medians                     -0.011844
# Road_allignment                      -0.005967
# Types_of_Junction                    -0.008861
# Road_surface_type                    -0.004510
# Road_surface_conditions               0.004579
# Light_conditions                      0.025741
# Weather_conditions                    0.010172
# Type_of_collision                     0.025867
# Number_of_vehicles_involved           0.096023
# Number_of_casualties                 -0.045339
# Vehicle_movement                     -0.010386
# Casualty_class                        0.014075
# Sex_of_casualty                       0.003708
# Age_band_of_casualty                  0.025510
# Casualty_severity                     0.006531
# Pedestrian_movement                   0.013082
# Cause_of_accident                     0.008040
# Accident_severity                     1.000000
#
# [27 rows x 27 columns]

# %%
print(numeric_df.head())
print("Columns in numeric_df:", numeric_df.columns)
# Out:
#    Number_of_vehicles_involved  Number_of_casualties
# 0                            2                     2
# 1                            2                     2
# 2                            2                     2
# 3                            2                     2
# 4                            2                     2
# Columns in numeric_df: Index(['Number_of_vehicles_involved', 'Number_of_casualties'], dtype='object')

# %%
print(numeric_df.isnull().sum())
print(numeric_df.describe())
# Out:
# Number_of_vehicles_involved    0
# Number_of_casualties           0
# dtype: int64
#        Number_of_vehicles_involved  Number_of_casualties
# count                 12316.000000          12316.000000
# mean                      2.040679              1.548149
# std                       0.688790              1.007179
# min                       1.000000              1.000000
# 25%                       2.000000              1.000000
# 50%                       2.000000              1.000000
# 75%                       2.000000              2.000000
# max                       7.000000              8.000000

# %%
pip install seaborn
# Out:
# Defaulting to user installation because normal site-packages is not writeableNote: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: seaborn in c:\users\tanuvedu\appdata\roaming\python\python311\site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\tanuvedu\appdata\roaming\python\python311\site-packages (from seaborn) (2.0.0)
# Requirement already satisfied: pandas>=1.2 in c:\users\tanuvedu\appdata\roaming\python\python311\site-packages (from seaborn) (2.2.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\tanuvedu\appdata\roaming\python\python311\site-packages (from seaborn) (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\tanuvedu\appdata\roaming\python\python311\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\tanuvedu\appdata\roaming\python\python311\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\tanuvedu\appdata\roaming\python\python311\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\tanuvedu\appdata\roaming\python\python311\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in c:\users\tanuvedu\appdata\roaming\python\python311\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\tanuvedu\appdata\roaming\python\python311\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\tanuvedu\appdata\roaming\python\python311\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\tanuvedu\appdata\roaming\python\python311\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\tanuvedu\appdata\roaming\python\python311\site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\tanuvedu\appdata\roaming\python\python311\site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: six>=1.5 in c:\users\tanuvedu\appdata\roaming\python\python311\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.16.0)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.heatmap(correlation_matrix, annot=True, cmap="viridis")
plt.show()

# %%
numerical=[i for i in df.columns if df[i].dtype!='O']
print('The numerica variables are',numerical)
# Out:
# The numerica variables are ['Number_of_vehicles_involved', 'Number_of_casualties']

# %%
#distribution for numerical columns
plt.figure(figsize=(10,10))
plotnumber = 1
for i in numerical:
    if plotnumber <= df.shape[1]:
        ax1 = plt.subplot(2,2,plotnumber)
        plt.hist(df[i],color='red')
        plt.xticks(fontsize=12)
        plt.yticks(fontsize=12)
        plt.title('frequency of '+i, fontsize=10)
    plotnumber +=1

# %%
plt.figure(figsize=(10,200))
plotnumber = 1

for col in categorical:
    if plotnumber <= df.shape[1] and col!='Pedestrian_movement':
        ax1 = plt.subplot(28,1,plotnumber)
        sns.countplot(data=df, y=col, palette='muted')
        plt.xticks(fontsize=12)
        plt.yticks(fontsize=12)
        plt.title(col.title(), fontsize=14)
        plt.xlabel('')
        plt.ylabel('')
    plotnumber +=1

# %%
df.dtypes
# Out:
# Day_of_week                    int64
# Age_band_of_driver             int64
# Sex_of_driver                  int64
# Educational_level              int64
# Vehicle_driver_relation        int64
# Driving_experience             int64
# Type_of_vehicle                int64
# Owner_of_vehicle               int64
# Area_accident_occured          int64
# Lanes_or_Medians               int64
# Road_allignment                int64
# Types_of_Junction              int64
# Road_surface_type              int64
# Road_surface_conditions        int64
# Light_conditions               int64
# Weather_conditions             int64
# Type_of_collision              int64
# Number_of_vehicles_involved    int64
# Number_of_casualties           int64
# Vehicle_movement               int64
# Casualty_class                 int64
# Sex_of_casualty                int64
# Age_band_of_casualty           int64
# Casualty_severity              int64
# Pedestrian_movement            int64
# Cause_of_accident              int64
# Accident_severity              int64
# dtype: object

# %%
#importing label encoing module
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

#creating a new data frame from performing the chi2 analysis
df1=pd.DataFrame()

#adding all the categorical columns except the output to new data frame
for i in categorical:
    if i!= 'Accident_severity':
        df1[i]=le.fit_transform(df[i])

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12316 entries, 0 to 12315
# Data columns (total 24 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Day_of_week              12316 non-null  int64
#  1   Age_band_of_driver       12316 non-null  int64
#  2   Sex_of_driver            12316 non-null  int64
#  3   Educational_level        12316 non-null  int64
#  4   Vehicle_driver_relation  12316 non-null  int64
#  5   Driving_experience       12316 non-null  int64
#  6   Type_of_vehicle          12316 non-null  int64
#  7   Owner_of_vehicle         12316 non-null  int64
#  8   Area_accident_occured    12316 non-null  int64
#  9   Lanes_or_Medians         12316 non-null  int64
#  10  Road_allignment          12316 non-null  int64
#  11  Types_of_Junction        12316 non-null  int64
#  12  Road_surface_type        12316 non-null  int64
#  13  Road_surface_conditions  12316 non-null  int64
#  14  Light_conditions         12316 non-null  int64
#  15  Weather_conditions       12316 non-null  int64
#  16  Type_of_collision        12316 non-null  int64
#  17  Vehicle_movement         12316 non-null  int64
#  18  Casualty_class           12316 non-null  int64
#  19  Sex_of_casualty          12316 non-null  int64
#  20  Age_band_of_casualty     12316 non-null  int64
#  21  Casualty_severity        12316 non-null  int64
#  22  Pedestrian_movement      12316 non-null  int64
#  23  Cause_of_accident        12316 non-null  int64
# dtypes: int64(24)
# memory usage: 2.3 MB

# %%
plt.figure(figsize=(22,17))
sns.set(font_scale=1)
sns.heatmap(df1.corr(), annot=True)
# Out:
# <Axes: >

# %%
df1.head()
# Out:
#    Day_of_week  Age_band_of_driver  Sex_of_driver  Educational_level  \
# 0            1                   0              1                  0
# 1            1                   1              1                  4
# 2            1                   0              1                  4
# 3            3                   0              1                  4
# 4            3                   0              1                  4
#
#    Vehicle_driver_relation  Driving_experience  Type_of_vehicle  \
# 0                        0                   0                0
# 1                        0                   3               11
# 2                        0                   0                5
# 3                        0                   2               11
# 4                        0                   1                0
#
#    Owner_of_vehicle  Area_accident_occured  Lanes_or_Medians  ...  \
# 0                 3                      9                 2  ...
# 1                 3                      6                 4  ...
# 2                 3                      1                 6  ...
# 3                 0                      6                 6  ...
# 4                 3                      4                 6  ...
#
#    Light_conditions  Weather_conditions  Type_of_collision  Vehicle_movement  \
# 0                 3                   2                  3                 2
# 1                 3                   2                  8                 2
# 2                 3                   2                  2                 2
# 3                 0                   2                  8                 2
# 4                 0                   2                  8                 2
#
#    Casualty_class  Sex_of_casualty  Age_band_of_casualty  Casualty_severity  \
# 0               3                2                     5                  3
# 1               3                2                     5                  3
# 2               0                1                     1                  2
# 3               2                0                     0                  2
# 4               3                2                     5                  3
#
#    Pedestrian_movement  Cause_of_accident
# 0                    5                  9
# 1                    5                 16
# 2                    5                  0
# 3                    5                  1
# 4                    5                 16
#
# [5 rows x 24 columns]

# %%
from sklearn.feature_selection import chi2
f_p_values=chi2(df1,df['Accident_severity'])

# %%
f_p_values
# Out:
# (array([ 0.15822071,  8.91539214,  0.1431894 ,  0.17458477,  5.34534549,
#          4.49967858,  1.07767124,  1.10426215,  3.61654037,  3.28161464,
#          0.1319306 ,  3.08648691,  6.99480557,  0.61510308, 16.08282359,
#          1.14934538, 10.09632283,  2.20071197,  3.2168602 ,  0.12594479,
#         13.77841337,  0.20273788,  0.39747982,  3.19366551]),
#  array([9.23937958e-01, 1.15890328e-02, 9.30908116e-01, 9.16409114e-01,
#         6.90673790e-02, 1.05416165e-01, 5.83427189e-01, 5.75721597e-01,
#         1.63937473e-01, 1.93823502e-01, 9.36163348e-01, 2.13686893e-01,
#         3.02759144e-02, 7.35244973e-01, 3.21854237e-04, 5.62889079e-01,
#         6.42112839e-03, 3.32752607e-01, 2.00201664e-01, 9.38969394e-01,
#         1.01872169e-03, 9.03599597e-01, 8.19763078e-01, 2.02536988e-01]))

# %%
f_p_values1=pd.DataFrame({'features':df1.columns, 'Fscore': f_p_values[0], 'Pvalues':f_p_values[1]})
f_p_values1
# Out:
#                    features     Fscore   Pvalues
# 0               Day_of_week   0.158221  0.923938
# 1        Age_band_of_driver   8.915392  0.011589
# 2             Sex_of_driver   0.143189  0.930908
# 3         Educational_level   0.174585  0.916409
# 4   Vehicle_driver_relation   5.345345  0.069067
# 5        Driving_experience   4.499679  0.105416
# 6           Type_of_vehicle   1.077671  0.583427
# 7          Owner_of_vehicle   1.104262  0.575722
# 8     Area_accident_occured   3.616540  0.163937
# 9          Lanes_or_Medians   3.281615  0.193824
# 10          Road_allignment   0.131931  0.936163
# 11        Types_of_Junction   3.086487  0.213687
# 12        Road_surface_type   6.994806  0.030276
# 13  Road_surface_conditions   0.615103  0.735245
# 14         Light_conditions  16.082824  0.000322
# 15       Weather_conditions   1.149345  0.562889
# 16        Type_of_collision  10.096323  0.006421
# 17         Vehicle_movement   2.200712  0.332753
# 18           Casualty_class   3.216860  0.200202
# 19          Sex_of_casualty   0.125945  0.938969
# 20     Age_band_of_casualty  13.778413  0.001019
# 21        Casualty_severity   0.202738  0.903600
# 22      Pedestrian_movement   0.397480  0.819763
# 23        Cause_of_accident   3.193666  0.202537

# %%
f_p_values1.sort_values(by='Pvalues',ascending=True)
# Out:
#                    features     Fscore   Pvalues
# 14         Light_conditions  16.082824  0.000322
# 20     Age_band_of_casualty  13.778413  0.001019
# 16        Type_of_collision  10.096323  0.006421
# 1        Age_band_of_driver   8.915392  0.011589
# 12        Road_surface_type   6.994806  0.030276
# 4   Vehicle_driver_relation   5.345345  0.069067
# 5        Driving_experience   4.499679  0.105416
# 8     Area_accident_occured   3.616540  0.163937
# 9          Lanes_or_Medians   3.281615  0.193824
# 18           Casualty_class   3.216860  0.200202
# 23        Cause_of_accident   3.193666  0.202537
# 11        Types_of_Junction   3.086487  0.213687
# 17         Vehicle_movement   2.200712  0.332753
# 15       Weather_conditions   1.149345  0.562889
# 7          Owner_of_vehicle   1.104262  0.575722
# 6           Type_of_vehicle   1.077671  0.583427
# 13  Road_surface_conditions   0.615103  0.735245
# 22      Pedestrian_movement   0.397480  0.819763
# 21        Casualty_severity   0.202738  0.903600
# 3         Educational_level   0.174585  0.916409
# 0               Day_of_week   0.158221  0.923938
# 2             Sex_of_driver   0.143189  0.930908
# 10          Road_allignment   0.131931  0.936163
# 19          Sex_of_casualty   0.125945  0.938969

# %%
df2=df.drop(['Owner_of_vehicle', 'Type_of_vehicle', 'Road_surface_conditions', 'Pedestrian_movement',
         'Casualty_severity','Educational_level','Day_of_week','Sex_of_driver','Road_allignment',
         'Sex_of_casualty'],axis=1)
df2.head()
# Out:
#    Age_band_of_driver  Vehicle_driver_relation  Driving_experience  \
# 0                   0                        0                   0
# 1                   1                        0                   3
# 2                   0                        0                   0
# 3                   0                        0                   2
# 4                   0                        0                   1
#
#    Area_accident_occured  Lanes_or_Medians  Types_of_Junction  \
# 0                      9                 2                  1
# 1                      6                 4                  1
# 2                      1                 6                  1
# 3                      6                 6                  7
# 4                      4                 6                  7
#
#    Road_surface_type  Light_conditions  Weather_conditions  Type_of_collision  \
# 0                  0                 3                   2                  3
# 1                  0                 3                   2                  8
# 2                  0                 3                   2                  2
# 3                  2                 0                   2                  8
# 4                  0                 0                   2                  8
#
#    Number_of_vehicles_involved  Number_of_casualties  Vehicle_movement  \
# 0                            2                     2                 2
# 1                            2                     2                 2
# 2                            2                     2                 2
# 3                            2                     2                 2
# 4                            2                     2                 2
#
#    Casualty_class  Age_band_of_casualty  Cause_of_accident  Accident_severity
# 0               3                     5                  9                  2
# 1               3                     5                 16                  2
# 2               0                     1                  0                  1
# 3               2                     0                  1                  2
# 4               3                     5                 16                  2

# %%
df2.shape
# Out:
# (12316, 17)

# %%
df2.shape
# Out:
# (12316, 17)

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12316 entries, 0 to 12315
# Data columns (total 17 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Age_band_of_driver           12316 non-null  int64
#  1   Vehicle_driver_relation      12316 non-null  int64
#  2   Driving_experience           12316 non-null  int64
#  3   Area_accident_occured        12316 non-null  int64
#  4   Lanes_or_Medians             12316 non-null  int64
#  5   Types_of_Junction            12316 non-null  int64
#  6   Road_surface_type            12316 non-null  int64
#  7   Light_conditions             12316 non-null  int64
#  8   Weather_conditions           12316 non-null  int64
#  9   Type_of_collision            12316 non-null  int64
#  10  Number_of_vehicles_involved  12316 non-null  int64
#  11  Number_of_casualties         12316 non-null  int64
#  12  Vehicle_movement             12316 non-null  int64
#  13  Casualty_class               12316 non-null  int64
#  14  Age_band_of_casualty         12316 non-null  int64
#  15  Cause_of_accident            12316 non-null  int64
#  16  Accident_severity            12316 non-null  int64
# dtypes: int64(17)
# memory usage: 1.6 MB

# %%
categorical_new=[i for i in df2.columns if df2[i].dtype=='O']
print(categorical_new)
# Out:
# []

# %%
for i in categorical_new:
    print(df2[i].value_counts())

# %%
dummy=pd.get_dummies(df2[['Age_band_of_driver', 'Vehicle_driver_relation', 'Driving_experience',
                          'Area_accident_occured', 'Lanes_or_Medians', 'Types_of_Junction', 'Road_surface_type', 
                          'Light_conditions', 'Weather_conditions', 'Type_of_collision', 'Vehicle_movement', 
                          'Casualty_class', 'Age_band_of_casualty', 'Cause_of_accident']],drop_first=True)
dummy.head()
# Out:
#    Age_band_of_driver  Vehicle_driver_relation  Driving_experience  \
# 0                   0                        0                   0
# 1                   1                        0                   3
# 2                   0                        0                   0
# 3                   0                        0                   2
# 4                   0                        0                   1
#
#    Area_accident_occured  Lanes_or_Medians  Types_of_Junction  \
# 0                      9                 2                  1
# 1                      6                 4                  1
# 2                      1                 6                  1
# 3                      6                 6                  7
# 4                      4                 6                  7
#
#    Road_surface_type  Light_conditions  Weather_conditions  Type_of_collision  \
# 0                  0                 3                   2                  3
# 1                  0                 3                   2                  8
# 2                  0                 3                   2                  2
# 3                  2                 0                   2                  8
# 4                  0                 0                   2                  8
#
#    Vehicle_movement  Casualty_class  Age_band_of_casualty  Cause_of_accident
# 0                 2               3                     5                  9
# 1                 2               3                     5                 16
# 2                 2               0                     1                  0
# 3                 2               2                     0                  1
# 4                 2               3                     5                 16

# %%
df3=pd.concat([df2,dummy],axis=1)
df3.head()
# Out:
#    Age_band_of_driver  Vehicle_driver_relation  Driving_experience  \
# 0                   0                        0                   0
# 1                   1                        0                   3
# 2                   0                        0                   0
# 3                   0                        0                   2
# 4                   0                        0                   1
#
#    Area_accident_occured  Lanes_or_Medians  Types_of_Junction  \
# 0                      9                 2                  1
# 1                      6                 4                  1
# 2                      1                 6                  1
# 3                      6                 6                  7
# 4                      4                 6                  7
#
#    Road_surface_type  Light_conditions  Weather_conditions  Type_of_collision  \
# 0                  0                 3                   2                  3
# 1                  0                 3                   2                  8
# 2                  0                 3                   2                  2
# 3                  2                 0                   2                  8
# 4                  0                 0                   2                  8
#
#    ...  Lanes_or_Medians  Types_of_Junction  Road_surface_type  \
# 0  ...                 2                  1                  0
# 1  ...                 4                  1                  0
# 2  ...                 6                  1                  0
# 3  ...                 6                  7                  2
# 4  ...                 6                  7                  0
#
#    Light_conditions  Weather_conditions  Type_of_collision  Vehicle_movement  \
# 0                 3                   2                  3                 2
# 1                 3                   2                  8                 2
# 2                 3                   2                  2                 2
# 3                 0                   2                  8                 2
# 4                 0                   2                  8                 2
#
#    Casualty_class  Age_band_of_casualty  Cause_of_accident
# 0               3                     5                  9
# 1               3                     5                 16
# 2               0                     1                  0
# 3               2                     0                  1
# 4               3                     5                 16
#
# [5 rows x 31 columns]

# %%
df3.drop(['Age_band_of_driver', 'Vehicle_driver_relation', 'Driving_experience', 'Area_accident_occured', 'Lanes_or_Medians',
          'Types_of_Junction', 'Road_surface_type', 'Light_conditions', 'Weather_conditions', 'Type_of_collision',
          'Vehicle_movement','Casualty_class', 'Age_band_of_casualty', 'Cause_of_accident'],axis=1,inplace=True)
df3.head()
# Out:
#    Number_of_vehicles_involved  Number_of_casualties  Accident_severity
# 0                            2                     2                  2
# 1                            2                     2                  2
# 2                            2                     2                  1
# 3                            2                     2                  2
# 4                            2                     2                  2

# %%
x=df3.drop(['Accident_severity'],axis=1)
x.shape
# Out:
# (12316, 2)

# %%
x.head()
# Out:
#    Number_of_vehicles_involved  Number_of_casualties
# 0                            2                     2
# 1                            2                     2
# 2                            2                     2
# 3                            2                     2
# 4                            2                     2

# %%
y=df3.iloc[:,2]
y.head()
# Out:
# 0    2
# 1    2
# 2    1
# 3    2
# 4    2
# Name: Accident_severity, dtype: int64

# %%
y.value_counts()
# Out:
# Accident_severity
# 2    10415
# 1     1743
# 0      158
# Name: count, dtype: int64

# %%
sns.countplot(x = y, palette='muted')
# Out:
# <Axes: xlabel='Accident_severity', ylabel='count'>

# %%
# !pip install imbalanced-learn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting imbalanced-learn
#   Downloading imbalanced_learn-0.13.0-py3-none-any.whl.metadata (8.8 kB)
# Requirement already satisfied: numpy<3,>=1.24.3 in c:\users\tanuvedu\appdata\roaming\python\python311\site-packages (from imbalanced-learn) (2.0.0)
# Requirement already satisfied: scipy<2,>=1.10.1 in c:\users\tanuvedu\appdata\roaming\python\python311\site-packages (from imbalanced-learn) (1.14.1)
# Requirement already satisfied: scikit-learn<2,>=1.3.2 in c:\users\tanuvedu\appdata\roaming\python\python311\site-packages (from imbalanced-learn) (1.5.2)
# Collecting sklearn-compat<1,>=0.1 (from imbalanced-learn)
#   Downloading sklearn_compat-0.1.3-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: joblib<2,>=1.1.1 in c:\users\tanuvedu\appdata\roaming\python\python311\site-packages (from imbalanced-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl<4,>=2.0.0 in c:\users\tanuvedu\appdata\roaming\python\python311\site-packages (from imbalanced-learn) (3.5.0)
# Downloading imbalanced_learn-0.13.0-py3-none-any.whl (238 kB)
# Downloading sklearn_compat-0.1.3-py3-none-any.whl (18 kB)
# Installing collected packages: sklearn-compat, imbalanced-learn
# Successfully installed imbalanced-learn-0.13.0 sklearn-compat-0.1.3

# %%
print(df.head())  # Display the first few rows of the dataset
# Out:
#        Time Day_of_week Age_band_of_driver Sex_of_driver   Educational_level  \
# 0  17:02:00      Monday              18-30          Male   Above high school
# 1  17:02:00      Monday              31-50          Male  Junior high school
# 2  17:02:00      Monday              18-30          Male  Junior high school
# 3   1:06:00      Sunday              18-30          Male  Junior high school
# 4   1:06:00      Sunday              18-30          Male  Junior high school
#
#   Vehicle_driver_relation Driving_experience      Type_of_vehicle  \
# 0                Employee              1-2yr           Automobile
# 1                Employee         Above 10yr  Public (> 45 seats)
# 2                Employee              1-2yr      Lorry (41?100Q)
# 3                Employee             5-10yr  Public (> 45 seats)
# 4                Employee              2-5yr                  NaN
#
#   Owner_of_vehicle Service_year_of_vehicle  ... Vehicle_movement  \
# 0            Owner              Above 10yr  ...   Going straight
# 1            Owner                 5-10yrs  ...   Going straight
# 2            Owner                     NaN  ...   Going straight
# 3     Governmental                     NaN  ...   Going straight
# 4            Owner                 5-10yrs  ...   Going straight
#
#     Casualty_class Sex_of_casualty Age_band_of_casualty Casualty_severity  \
# 0               na              na                   na                na
# 1               na              na                   na                na
# 2  Driver or rider            Male                31-50                 3
# 3       Pedestrian          Female                18-30                 3
# 4               na              na                   na                na
#
#   Work_of_casuality Fitness_of_casuality Pedestrian_movement  \
# 0               NaN                  NaN    Not a Pedestrian
# 1               NaN                  NaN    Not a Pedestrian
# 2            Driver                  NaN    Not a Pedestrian
# 3            Driver               Normal    Not a Pedestrian
# 4               NaN                  NaN    Not a Pedestrian
#
#             Cause_of_accident Accident_severity
# 0             Moving Backward     Slight Injury
# 1                  Overtaking     Slight Injury
# 2   Changing lane to the left    Serious Injury
# 3  Changing lane to the right     Slight Injury
# 4                  Overtaking     Slight Injury
#
# [5 rows x 32 columns]

# %%
correlation_matrix = df.select_dtypes(include=[float, int]).corr()
print(correlation_matrix)
# Out:
#                              Number_of_vehicles_involved  Number_of_casualties
# Number_of_vehicles_involved                     1.000000              0.213427
# Number_of_casualties                            0.213427              1.000000

# %%
print(df.dtypes)
# Out:
# Time                           object
# Day_of_week                    object
# Age_band_of_driver             object
# Sex_of_driver                  object
# Educational_level              object
# Vehicle_driver_relation        object
# Driving_experience             object
# Type_of_vehicle                object
# Owner_of_vehicle               object
# Service_year_of_vehicle        object
# Defect_of_vehicle              object
# Area_accident_occured          object
# Lanes_or_Medians               object
# Road_allignment                object
# Types_of_Junction              object
# Road_surface_type              object
# Road_surface_conditions        object
# Light_conditions               object
# Weather_conditions             object
# Type_of_collision              object
# Number_of_vehicles_involved     int64
# Number_of_casualties            int64
# Vehicle_movement               object
# Casualty_class                 object
# Sex_of_casualty                object
# Age_band_of_casualty           object
# Casualty_severity              object
# Work_of_casuality              object
# Fitness_of_casuality           object
# Pedestrian_movement            object
# Cause_of_accident              object
# Accident_severity              object
# dtype: object

# %%
print(df.isnull().sum())
print(df.duplicated().sum())
# Out:
# Time                           0
# Day_of_week                    0
# Age_band_of_driver             0
# Sex_of_driver                  0
# Educational_level              0
# Vehicle_driver_relation        0
# Driving_experience             0
# Type_of_vehicle                0
# Owner_of_vehicle               0
# Service_year_of_vehicle        0
# Defect_of_vehicle              0
# Area_accident_occured          0
# Lanes_or_Medians               0
# Road_allignment                0
# Types_of_Junction              0
# Road_surface_type              0
# Road_surface_conditions        0
# Light_conditions               0
# Weather_conditions             0
# Type_of_collision              0
# Number_of_vehicles_involved    0
# Number_of_casualties           0
# Vehicle_movement               0
# Casualty_class                 0
# Sex_of_casualty                0
# Age_band_of_casualty           0
# Casualty_severity              0
# Work_of_casuality              0
# Fitness_of_casuality           0
# Pedestrian_movement            0
# Cause_of_accident              0
# Accident_severity              0
# dtype: int64
# 0

# %%
# Replace 'Accident_severity' with the actual target column you want
target_column = 'Accident_severity'
x = df.drop(columns=[target_column])  # Features
y = df[target_column]  # Target

# %%
print(df.columns)
# Out:
# Index(['Time', 'Day_of_week', 'Age_band_of_driver', 'Sex_of_driver',
#        'Educational_level', 'Vehicle_driver_relation', 'Driving_experience',
#        'Type_of_vehicle', 'Owner_of_vehicle', 'Service_year_of_vehicle',
#        'Defect_of_vehicle', 'Area_accident_occured', 'Lanes_or_Medians',
#        'Road_allignment', 'Types_of_Junction', 'Road_surface_type',
#        'Road_surface_conditions', 'Light_conditions', 'Weather_conditions',
#        'Type_of_collision', 'Number_of_vehicles_involved',
#        'Number_of_casualties', 'Vehicle_movement', 'Casualty_class',
#        'Sex_of_casualty', 'Age_band_of_casualty', 'Casualty_severity',
#        'Work_of_casuality', 'Fitness_of_casuality', 'Pedestrian_movement',
#        'Cause_of_accident', 'Accident_severity'],
#       dtype='object')

# %%
non_numeric_cols = df.select_dtypes(include=['object']).columns
print(f"Non-numeric columns: {non_numeric_cols}")
# Out:
# Non-numeric columns: Index(['Time', 'Day_of_week', 'Age_band_of_driver', 'Sex_of_driver',
#        'Educational_level', 'Vehicle_driver_relation', 'Driving_experience',
#        'Type_of_vehicle', 'Owner_of_vehicle', 'Service_year_of_vehicle',
#        'Defect_of_vehicle', 'Area_accident_occured', 'Lanes_or_Medians',
#        'Road_allignment', 'Types_of_Junction', 'Road_surface_type',
#        'Road_surface_conditions', 'Light_conditions', 'Weather_conditions',
#        'Type_of_collision', 'Vehicle_movement', 'Casualty_class',
#        'Sex_of_casualty', 'Age_band_of_casualty', 'Casualty_severity',
#        'Work_of_casuality', 'Fitness_of_casuality', 'Pedestrian_movement',
#        'Cause_of_accident', 'Accident_severity'],
#       dtype='object')

# %%
from sklearn.preprocessing import LabelEncoder

# Replace non-numeric columns with appropriate encoding
for col in non_numeric_cols:
    if col != 'Accident_severity':  # We don't want to encode the target
        df[col] = LabelEncoder().fit_transform(df[col])

# Now apply chi-square test again
x = df.drop(columns=['Accident_severity'])  # Features
y = df['Accident_severity']  # Target

from sklearn.feature_selection import chi2

chi2_values, p_values = chi2(x, y)

# Print p-values for each feature
feature_names = x.columns
for feature, p_val in zip(feature_names, p_values):
    print(f"Feature: {feature}, p-value: {p_val}")
# Out:
# Feature: Time, p-value: 4.85315861549572e-151
# Feature: Day_of_week, p-value: 0.9239379580515421
# Feature: Age_band_of_driver, p-value: 0.01158903284831885
# Feature: Sex_of_driver, p-value: 0.930908115859155
# Feature: Educational_level, p-value: 0.5876201937562113
# Feature: Vehicle_driver_relation, p-value: 0.033458269811253764
# Feature: Driving_experience, p-value: 0.18662690553985875
# Feature: Type_of_vehicle, p-value: 0.015099618085240936
# Feature: Owner_of_vehicle, p-value: 0.544503181835351
# Feature: Service_year_of_vehicle, p-value: 0.9106813489976593
# Feature: Defect_of_vehicle, p-value: 0.8450560185926848
# Feature: Area_accident_occured, p-value: 0.16859936805818151
# Feature: Lanes_or_Medians, p-value: 0.2299524819743405
# Feature: Road_allignment, p-value: 0.9051583124148478
# Feature: Types_of_Junction, p-value: 0.1335358744564745
# Feature: Road_surface_type, p-value: 0.022055239626012208
# Feature: Road_surface_conditions, p-value: 0.7352449726830435
# Feature: Light_conditions, p-value: 0.00032185423673593457
# Feature: Weather_conditions, p-value: 0.5628890790342622
# Feature: Type_of_collision, p-value: 0.00981899205229277
# Feature: Number_of_vehicles_involved, p-value: 1.5730122610420924e-06
# Feature: Number_of_casualties, p-value: 7.221135840248148e-15
# Feature: Vehicle_movement, p-value: 0.00340868428535536
# Feature: Casualty_class, p-value: 0.20020166385448557
# Feature: Sex_of_casualty, p-value: 0.938969393992553
# Feature: Age_band_of_casualty, p-value: 0.001018721686133598
# Feature: Casualty_severity, p-value: 0.9035995970929009
# Feature: Work_of_casuality, p-value: 0.8921802454671572
# Feature: Fitness_of_casuality, p-value: 0.945582833420233
# Feature: Pedestrian_movement, p-value: 0.819763078482204
# Feature: Cause_of_accident, p-value: 0.20253698765936692

# %%
#after evaluating we are removing lesser important columns and storing to a new data frame
df2=df.drop(['Owner_of_vehicle', 'Type_of_vehicle', 'Road_surface_conditions', 'Pedestrian_movement',
         'Casualty_severity','Educational_level','Day_of_week','Sex_of_driver','Road_allignment',
         'Sex_of_casualty'],axis=1)
df2.head()
# Out:
#    Time  Age_band_of_driver  Vehicle_driver_relation  Driving_experience  \
# 0   420                   0                        0                   0
# 1   420                   1                        0                   3
# 2   420                   0                        0                   0
# 3   594                   0                        0                   2
# 4   594                   0                        0                   1
#
#    Service_year_of_vehicle  Defect_of_vehicle  Area_accident_occured  \
# 0                        3                  2                      9
# 1                        2                  2                      6
# 2                        6                  2                      1
# 3                        6                  2                      6
# 4                        2                  2                      4
#
#    Lanes_or_Medians  Types_of_Junction  Road_surface_type  ...  \
# 0                 7                  1                  0  ...
# 1                 4                  1                  0  ...
# 2                 6                  1                  0  ...
# 3                 6                  7                  2  ...
# 4                 6                  7                  0  ...
#
#    Type_of_collision  Number_of_vehicles_involved  Number_of_casualties  \
# 0                  3                            2                     2
# 1                  8                            2                     2
# 2                  2                            2                     2
# 3                  8                            2                     2
# 4                  8                            2                     2
#
#    Vehicle_movement  Casualty_class  Age_band_of_casualty  Work_of_casuality  \
# 0                 2               3                     5                  7
# 1                 2               3                     5                  7
# 2                 2               0                     1                  0
# 3                 2               2                     0                  0
# 4                 2               3                     5                  7
#
#    Fitness_of_casuality  Cause_of_accident  Accident_severity
# 0                     5                  9      Slight Injury
# 1                     5                 16      Slight Injury
# 2                     5                  0     Serious Injury
# 3                     2                  1      Slight Injury
# 4                     5                 16      Slight Injury
#
# [5 rows x 22 columns]

# %%
df2.shape
# Out:
# (12316, 22)

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12316 entries, 0 to 12315
# Data columns (total 22 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Time                         12316 non-null  int64
#  1   Age_band_of_driver           12316 non-null  int64
#  2   Vehicle_driver_relation      12316 non-null  int64
#  3   Driving_experience           12316 non-null  int64
#  4   Service_year_of_vehicle      12316 non-null  int64
#  5   Defect_of_vehicle            12316 non-null  int64
#  6   Area_accident_occured        12316 non-null  int64
#  7   Lanes_or_Medians             12316 non-null  int64
#  8   Types_of_Junction            12316 non-null  int64
#  9   Road_surface_type            12316 non-null  int64
#  10  Light_conditions             12316 non-null  int64
#  11  Weather_conditions           12316 non-null  int64
#  12  Type_of_collision            12316 non-null  int64
#  13  Number_of_vehicles_involved  12316 non-null  int64
#  14  Number_of_casualties         12316 non-null  int64
#  15  Vehicle_movement             12316 non-null  int64
#  16  Casualty_class               12316 non-null  int64
#  17  Age_band_of_casualty         12316 non-null  int64
#  18  Work_of_casuality            12316 non-null  int64
#  19  Fitness_of_casuality         12316 non-null  int64
#  20  Cause_of_accident            12316 non-null  int64
#  21  Accident_severity            12316 non-null  object
# dtypes: int64(21), object(1)
# memory usage: 2.1+ MB

# %%
for column in categorical_new:
    print(f"Unique values in {column}: {df2[column].unique()}")
# Out:
# Unique values in Accident_severity: ['Slight Injury' 'Serious Injury' 'Fatal injury']

# %%
for i in categorical_new:
    print(df2[i].value_counts())
# Out:
# Accident_severity
# Slight Injury     10415
# Serious Injury     1743
# Fatal injury        158
# Name: count, dtype: int64

# %%
#get_dummies
dummy=pd.get_dummies(df2[['Age_band_of_driver', 'Vehicle_driver_relation', 'Driving_experience',
                          'Area_accident_occured', 'Lanes_or_Medians', 'Types_of_Junction', 'Road_surface_type', 
                          'Light_conditions', 'Weather_conditions', 'Type_of_collision', 'Vehicle_movement', 
                          'Casualty_class', 'Age_band_of_casualty', 'Cause_of_accident']],drop_first=True)
dummy.head()
# Out:
#    Age_band_of_driver  Vehicle_driver_relation  Driving_experience  \
# 0                   0                        0                   0
# 1                   1                        0                   3
# 2                   0                        0                   0
# 3                   0                        0                   2
# 4                   0                        0                   1
#
#    Area_accident_occured  Lanes_or_Medians  Types_of_Junction  \
# 0                      9                 7                  1
# 1                      6                 4                  1
# 2                      1                 6                  1
# 3                      6                 6                  7
# 4                      4                 6                  7
#
#    Road_surface_type  Light_conditions  Weather_conditions  Type_of_collision  \
# 0                  0                 3                   2                  3
# 1                  0                 3                   2                  8
# 2                  0                 3                   2                  2
# 3                  2                 0                   2                  8
# 4                  0                 0                   2                  8
#
#    Vehicle_movement  Casualty_class  Age_band_of_casualty  Cause_of_accident
# 0                 2               3                     5                  9
# 1                 2               3                     5                 16
# 2                 2               0                     1                  0
# 3                 2               2                     0                  1
# 4                 2               3                     5                 16

# %%
#concatinate dummy and old data frame
df3=pd.concat([df2,dummy],axis=1)
df3.head()
# Out:
#    Time  Age_band_of_driver  Vehicle_driver_relation  Driving_experience  \
# 0   420                   0                        0                   0
# 1   420                   1                        0                   3
# 2   420                   0                        0                   0
# 3   594                   0                        0                   2
# 4   594                   0                        0                   1
#
#    Service_year_of_vehicle  Defect_of_vehicle  Area_accident_occured  \
# 0                        3                  2                      9
# 1                        2                  2                      6
# 2                        6                  2                      1
# 3                        6                  2                      6
# 4                        2                  2                      4
#
#    Lanes_or_Medians  Types_of_Junction  Road_surface_type  ...  \
# 0                 7                  1                  0  ...
# 1                 4                  1                  0  ...
# 2                 6                  1                  0  ...
# 3                 6                  7                  2  ...
# 4                 6                  7                  0  ...
#
#    Lanes_or_Medians  Types_of_Junction  Road_surface_type  Light_conditions  \
# 0                 7                  1                  0                 3
# 1                 4                  1                  0                 3
# 2                 6                  1                  0                 3
# 3                 6                  7                  2                 0
# 4                 6                  7                  0                 0
#
#    Weather_conditions  Type_of_collision  Vehicle_movement  Casualty_class  \
# 0                   2                  3                 2               3
# 1                   2                  8                 2               3
# 2                   2                  2                 2               0
# 3                   2                  8                 2               2
# 4                   2                  8                 2               3
#
#    Age_band_of_casualty  Cause_of_accident
# 0                     5                  9
# 1                     5                 16
# 2                     1                  0
# 3                     0                  1
# 4                     5                 16
#
# [5 rows x 36 columns]

# %%
#dropping dummied columns
df3.drop(['Age_band_of_driver', 'Vehicle_driver_relation', 'Driving_experience', 'Area_accident_occured', 'Lanes_or_Medians',
          'Types_of_Junction', 'Road_surface_type', 'Light_conditions', 'Weather_conditions', 'Type_of_collision',
          'Vehicle_movement','Casualty_class', 'Age_band_of_casualty', 'Cause_of_accident'],axis=1,inplace=True)
df3.head()
# Out:
#    Time  Service_year_of_vehicle  Defect_of_vehicle  \
# 0   420                        3                  2
# 1   420                        2                  2
# 2   420                        6                  2
# 3   594                        6                  2
# 4   594                        2                  2
#
#    Number_of_vehicles_involved  Number_of_casualties  Work_of_casuality  \
# 0                            2                     2                  7
# 1                            2                     2                  7
# 2                            2                     2                  0
# 3                            2                     2                  0
# 4                            2                     2                  7
#
#    Fitness_of_casuality Accident_severity
# 0                     5     Slight Injury
# 1                     5     Slight Injury
# 2                     5    Serious Injury
# 3                     2     Slight Injury
# 4                     5     Slight Injury

# %%
print(df2['Accident_severity'].value_counts())
# Out:
# Accident_severity
# Slight Injury     10415
# Serious Injury     1743
# Fatal injury        158
# Name: count, dtype: int64

# %%
x.head()
# Out:
#    Time  Service_year_of_vehicle  Defect_of_vehicle  \
# 0   420                        3                  2
# 1   420                        2                  2
# 2   420                        6                  2
# 3   594                        6                  2
# 4   594                        2                  2
#
#    Number_of_vehicles_involved  Number_of_casualties  Work_of_casuality  \
# 0                            2                     2                  7
# 1                            2                     2                  7
# 2                            2                     2                  0
# 3                            2                     2                  0
# 4                            2                     2                  7
#
#    Fitness_of_casuality
# 0                     5
# 1                     5
# 2                     5
# 3                     2
# 4                     5

# %%
y = df2['Accident_severity']
print(y.head())
# Out:
# 0     Slight Injury
# 1     Slight Injury
# 2    Serious Injury
# 3     Slight Injury
# 4     Slight Injury
# Name: Accident_severity, dtype: object

# %%
y.value_counts()
# Out:
# Accident_severity
# Slight Injury     10415
# Serious Injury     1743
# Fatal injury        158
# Name: count, dtype: int64

# %%
sns.countplot(x = y, palette='muted')
# Out:
# C:\Users\TANUVEDU\AppData\Local\Temp\ipykernel_1548\1818022785.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x = y, palette='muted')
# <Axes: xlabel='Accident_severity', ylabel='count'>

# %%
#importing SMOTE 
from imblearn.over_sampling import SMOTE
oversample=SMOTE()
xo,yo=oversample.fit_resample(x,y)

# %%
y1=pd.DataFrame(yo)
y1.value_counts()
# Out:
# Accident_severity
# Fatal injury         10415
# Serious Injury       10415
# Slight Injury        10415
# Name: count, dtype: int64

# %%
sns.countplot(x = yo, palette='pastel')
# Out:
# C:\Users\TANUVEDU\AppData\Local\Temp\ipykernel_1548\1303798600.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x = yo, palette='pastel')
# <Axes: xlabel='Accident_severity', ylabel='count'>

# %%
from sklearn.model_selection import train_test_split
#splitting 70% of the data to training data and 30% of data to testing data
x_train,x_test,y_train,y_test=train_test_split(xo,yo,test_size=0.30,random_state=42)

# %%
print(x_train.shape,x_test.shape,y_train.shape,y_test.shape)
# Out:
# (21871, 7) (9374, 7) (21871,) (9374,)

# %%
#KNN model alg
from sklearn.neighbors import KNeighborsClassifier
model_KNN=KNeighborsClassifier(n_neighbors=5)
model_KNN.fit(x_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
y_pred=model_KNN.predict(x_test)

# %%
y_pred
# Out:
# array(['Serious Injury', 'Slight Injury', 'Slight Injury', ...,
#        'Fatal injury', 'Serious Injury', 'Serious Injury'], dtype=object)

# %%
from sklearn.metrics import classification_report,confusion_matrix,accuracy_score,ConfusionMatrixDisplay

# %%
report_KNN=classification_report(y_test,y_pred)
print(report_KNN)
# Out:
#                 precision    recall  f1-score   support
#
#   Fatal injury       0.89      0.96      0.93      3126
# Serious Injury       0.74      0.86      0.80      3144
#  Slight Injury       0.84      0.63      0.72      3104
#
#       accuracy                           0.82      9374
#      macro avg       0.82      0.82      0.81      9374
#   weighted avg       0.82      0.82      0.81      9374

# %%
accuracy_KNN=accuracy_score(y_test,y_pred)
print(accuracy_KNN)
# Out:
# 0.8193940687006614

# %%
matrix_KNN=confusion_matrix(y_test,y_pred)
print(matrix_KNN,'\n')
print(ConfusionMatrixDisplay.from_predictions(y_test,y_pred))
# Out:
# [[3013   69   44]
#  [ 105 2705  334]
#  [ 265  876 1963]]
#
# <sklearn.metrics._plot.confusion_matrix.ConfusionMatrixDisplay object at 0x00000149A0D6C7D0>
